# %% [markdown]
# # 0 Daten & Packages laden

# %%
import pandas as pd
import os
import gc
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
X_train = pd.read_parquet("/kaggle/input/axa-challenge-final/X_train_hyperparemeter_opt.parquet")
y_train = pd.read_parquet("/kaggle/input/axa-challenge-final/y_train_hyperparemeter_opt.parquet")

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 877416 entries, 3251228 to 8325804
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   tripduration          877416 non-null  int32
#  1   start station id      877416 non-null  float64
#  2   end station id        877416 non-null  float64
#  3   gender                877416 non-null  object
#  4   age                   877416 non-null  int32
#  5   month                 877416 non-null  int64
#  6   weekday               877416 non-null  object
#  7   time_hours            877416 non-null  int64
#  8   distance_travelled_m  877416 non-null  float32
#  9   same_start_end        877416 non-null  int64
#  10  is_holiday            877416 non-null  int8
# dtypes: float32(1), float64(2), int32(2), int64(3), int8(1), object(2)
# memory usage: 64.4+ MB

# %% [markdown]
# Datentransformationen sind notwendig weil einige Datenformate durch Parquet verloren gegangen sind

# %%
X_train["start station id"] = X_train["start station id"].astype("object")
X_train["end station id"] = X_train["end station id"].astype("object")
X_train["month"] = X_train["month"].astype("object")
X_train["time_hours"] = X_train["time_hours"].astype("object")

X_train["same_start_end"] = X_train["time_hours"].astype("int8")

# %% [markdown]
# # 6 Hyperparameter Optimierung verschiedener Modellansätze

# %% [markdown]
# ### 6.4 LGBM

# %% [markdown]
# Laden der Pakete und Pipelines

# %%
# %%capture
! pip install feature_engine

# %%
#Laden der Pakete
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import quantile_transform
from sklearn.preprocessing import FunctionTransformer
from feature_engine.encoding import RareLabelEncoder
from feature_engine.outliers import Winsorizer
from feature_engine.encoding import MeanEncoder
from sklearn.impute import SimpleImputer
from feature_engine.imputation import CategoricalImputer
from sklearn.preprocessing import KBinsDiscretizer

# %%
#Import der Pipelines und Definition der log_trans Funktion
import joblib

def log_trans(x):
    return np.log(x+0.01)

preprocessor_final_1 = joblib.load("/kaggle/input/axa-challenge-final/preprocessor_final_1.joblib")
preprocessor_final_2 = joblib.load("/kaggle/input/axa-challenge-final/preprocessor_final_2.joblib")

# %% [markdown]
# Durchführung von RandomizedSearchCV

# %%
from lightgbm import LGBMClassifier
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform


#Alle Schritte in eine Pipeline
Pipeline_lgbm_1 = Pipeline([("preprocessor_pipeline", preprocessor_final_1), 
                            ('lgbm', LGBMClassifier(random_state=1, reg_alpha=0.4) )])

Pipeline_lgbm_2 = Pipeline([("preprocessor_pipeline", preprocessor_final_2), 
                            ('lgbm', LGBMClassifier(random_state=1, reg_alpha=0.4) )])


lgbm_pipeline_list = [Pipeline_lgbm_1, Pipeline_lgbm_2]


param_grid_lgbm = dict(
    lgbm__n_estimators=randint(200, 600),
    lgbm__learning_rate=uniform(0.001, 0.1),
    lgbm__num_leaves=randint(31, 200),
    lgbm__max_depth=randint(-3, 10),
    lgbm__min_child_samples=randint(50, 100),
    )


dict_results_lgbm= {}

i=1
for p in lgbm_pipeline_list:
    np.random.seed(seed=99)
    search = RandomizedSearchCV(p, param_grid_lgbm, n_jobs=4, cv=4, verbose=4, scoring=["roc_auc", "accuracy"], refit=False, return_train_score=True, n_iter=40)
    search.fit(X_train, np.ravel(y_train) )
        
    dict_results_lgbm[i] = pd.DataFrame(search.cv_results_)
    
    print(i)
    i +=1
    gc.collect()
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# .datatable .frame thead tr.colnames {  background-image: url('data:image/png;base64,...');  background-repeat: repeat-x;  background-size: 14px;  height: 28px;}
# </style>
# Fitting 4 folds for each of 40 candidates, totalling 160 fits
# [CV 2/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.954, test=0.944) total time= 1.4min
# [CV 1/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.966, test=0.943) total time= 1.3min
# [CV 1/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.940, test=0.935) total time= 2.2min
# [CV 4/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.946, test=0.947) roc_auc: (train=0.918, test=0.920) total time=  36.5s
# [CV 4/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.944) roc_auc: (train=0.900, test=0.902) total time=  32.6s
# [CV 4/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.946, test=0.947) roc_auc: (train=0.917, test=0.918) total time=  53.4s
# [CV 4/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.954, test=0.952) roc_auc: (train=0.961, test=0.946) total time= 2.0min
# [CV 4/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.954, test=0.945) total time= 1.3min
# [CV 3/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.959, test=0.945) total time= 2.4min
# [CV 2/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.950) roc_auc: (train=0.946, test=0.940) total time= 1.8min
# [CV 3/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.940, test=0.937) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.948, test=0.945) total time= 1.4min
# [CV 2/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.975, test=0.943) total time= 1.8min
# [CV 2/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.972, test=0.944) total time= 1.8min
# [CV 2/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.949, test=0.949) roc_auc: (train=0.936, test=0.935) total time=  44.5s
# [CV 2/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.969, test=0.943) total time= 1.4min
# [CV 2/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.951, test=0.944) total time= 2.3min
# [CV 2/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.950, test=0.944) total time= 1.7min
# [CV 2/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.948, test=0.948) roc_auc: (train=0.931, test=0.930) total time= 1.2min
# [CV 2/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.944) total time= 2.6min
# [CV 3/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.952, test=0.945) total time= 1.6min
# [CV 3/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.970, test=0.945) total time= 1.5min
# [CV 3/4] END lgbm__learning_rate=0.004266133482097422, lgbm__max_depth=7, lgbm__min_child_samples=82, lgbm__n_estimators=576, lgbm__num_leaves=176; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.938, test=0.935) total time= 2.6min
# [CV 2/4] END lgbm__learning_rate=0.04363153129847165, lgbm__max_depth=4, lgbm__min_child_samples=75, lgbm__n_estimators=570, lgbm__num_leaves=169; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.946, test=0.943) total time= 1.5min
# [CV 1/4] END lgbm__learning_rate=0.04064314766640962, lgbm__max_depth=4, lgbm__min_child_samples=72, lgbm__n_estimators=338, lgbm__num_leaves=139; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.944, test=0.939) total time=  58.9s
# [CV 1/4] END lgbm__learning_rate=0.05498062156658356, lgbm__max_depth=-1, lgbm__min_child_samples=88, lgbm__n_estimators=448, lgbm__num_leaves=177; accuracy: (train=0.958, test=0.951) roc_auc: (train=0.976, test=0.943) total time= 1.7min
# [CV 1/4] END lgbm__learning_rate=0.030230751361551147, lgbm__max_depth=-1, lgbm__min_child_samples=89, lgbm__n_estimators=426, lgbm__num_leaves=162; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.964, test=0.943) total time= 2.0min
# [CV 1/4] END lgbm__learning_rate=0.059912934536355836, lgbm__max_depth=7, lgbm__min_child_samples=84, lgbm__n_estimators=418, lgbm__num_leaves=192; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.959, test=0.943) total time= 1.6min
# [CV 1/4] END lgbm__learning_rate=0.06581588203970642, lgbm__max_depth=3, lgbm__min_child_samples=65, lgbm__n_estimators=327, lgbm__num_leaves=98; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.943, test=0.939) total time=  50.2s
# [CV 1/4] END lgbm__learning_rate=0.0266292630148277, lgbm__max_depth=9, lgbm__min_child_samples=56, lgbm__n_estimators=527, lgbm__num_leaves=83; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.955, test=0.943) total time= 2.4min
# [CV 1/4] END lgbm__learning_rate=0.0424941284161412, lgbm__max_depth=6, lgbm__min_child_samples=84, lgbm__n_estimators=335, lgbm__num_leaves=154; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.950, test=0.942) total time= 1.2min
# [CV 1/4] END lgbm__learning_rate=0.08168766138390322, lgbm__max_depth=2, lgbm__min_child_samples=80, lgbm__n_estimators=393, lgbm__num_leaves=52; accuracy: (train=0.950, test=0.950) roc_auc: (train=0.940, test=0.937) total time=  49.6s
# [CV 1/4] END lgbm__learning_rate=0.03417034837206397, lgbm__max_depth=4, lgbm__min_child_samples=50, lgbm__n_estimators=270, lgbm__num_leaves=182; accuracy: (train=0.950, test=0.950) roc_auc: (train=0.942, test=0.938) total time=  47.5s
# [CV 1/4] END lgbm__learning_rate=0.008548100214480913, lgbm__max_depth=3, lgbm__min_child_samples=77, lgbm__n_estimators=588, lgbm__num_leaves=145; accuracy: (train=0.949, test=0.948) roc_auc: (train=0.931, test=0.928) total time= 1.5min
# [CV 1/4] END lgbm__learning_rate=0.05565296745349411, lgbm__max_depth=-3, lgbm__min_child_samples=51, lgbm__n_estimators=351, lgbm__num_leaves=111; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.965, test=0.943) total time= 1.4min[CV 4/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.954, test=0.946) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.966, test=0.946) total time= 1.3min
# [CV 4/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.950, test=0.951) roc_auc: (train=0.939, test=0.937) total time= 2.0min
# [CV 3/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.946, test=0.946) roc_auc: (train=0.919, test=0.918) total time=  37.1s
# [CV 3/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.943) roc_auc: (train=0.901, test=0.899) total time=  33.2s
# [CV 3/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.946, test=0.946) roc_auc: (train=0.917, test=0.916) total time=  53.8s
# [CV 3/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.961, test=0.946) total time= 2.0min
# [CV 1/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.954, test=0.943) total time= 1.5min
# [CV 2/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.944) total time= 2.6min
# [CV 4/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.945, test=0.941) total time= 1.8min
# [CV 2/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.941, test=0.936) total time= 1.4min
# [CV 2/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.949, test=0.944) total time= 1.5min
# [CV 3/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.974, test=0.945) total time= 1.7min
# [CV 3/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.972, test=0.946) total time= 2.0min
# [CV 3/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.949, test=0.949) roc_auc: (train=0.936, test=0.936) total time=  44.0s
# [CV 3/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.968, test=0.945) total time= 1.5min
# [CV 3/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.950, test=0.945) total time= 2.3min
# [CV 3/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.950, test=0.945) total time= 1.6min
# [CV 3/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.948, test=0.948) roc_auc: (train=0.931, test=0.930) total time= 1.2min
# [CV 3/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.959, test=0.945) total time= 2.3min
# [CV 2/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.952, test=0.944) total time= 1.6min
# [CV 2/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.971, test=0.944) total time= 1.6min
# [CV 2/4] END lgbm__learning_rate=0.004266133482097422, lgbm__max_depth=7, lgbm__min_child_samples=82, lgbm__n_estimators=576, lgbm__num_leaves=176; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.938, test=0.934) total time= 2.9min
# [CV 3/4] END lgbm__learning_rate=0.04363153129847165, lgbm__max_depth=4, lgbm__min_child_samples=75, lgbm__n_estimators=570, lgbm__num_leaves=169; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.946, test=0.944) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.04064314766640962, lgbm__max_depth=4, lgbm__min_child_samples=72, lgbm__n_estimators=338, lgbm__num_leaves=139; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.943, test=0.942) total time=  54.9s
# [CV 3/4] END lgbm__learning_rate=0.05498062156658356, lgbm__max_depth=-1, lgbm__min_child_samples=88, lgbm__n_estimators=448, lgbm__num_leaves=177; accuracy: (train=0.958, test=0.951) roc_auc: (train=0.976, test=0.945) total time= 1.7min
# [CV 3/4] END lgbm__learning_rate=0.030230751361551147, lgbm__max_depth=-1, lgbm__min_child_samples=89, lgbm__n_estimators=426, lgbm__num_leaves=162; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.963, test=0.946) total time= 2.0min
# [CV 2/4] END lgbm__learning_rate=0.059912934536355836, lgbm__max_depth=7, lgbm__min_child_samples=84, lgbm__n_estimators=418, lgbm__num_leaves=192; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.959, test=0.944) total time= 1.5min
# [CV 2/4] END lgbm__learning_rate=0.06581588203970642, lgbm__max_depth=3, lgbm__min_child_samples=65, lgbm__n_estimators=327, lgbm__num_leaves=98; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.942, test=0.940) total time=  47.3s
# [CV 2/4] END lgbm__learning_rate=0.0266292630148277, lgbm__max_depth=9, lgbm__min_child_samples=56, lgbm__n_estimators=527, lgbm__num_leaves=83; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.955, test=0.944) total time= 2.4min
# [CV 2/4] END lgbm__learning_rate=0.0424941284161412, lgbm__max_depth=6, lgbm__min_child_samples=84, lgbm__n_estimators=335, lgbm__num_leaves=154; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.950, test=0.943) total time= 1.2min
# [CV 2/4] END lgbm__learning_rate=0.08168766138390322, lgbm__max_depth=2, lgbm__min_child_samples=80, lgbm__n_estimators=393, lgbm__num_leaves=52; accuracy: (train=0.950, test=0.950) roc_auc: (train=0.939, test=0.938) total time=  48.4s
# [CV 2/4] END lgbm__learning_rate=0.03417034837206397, lgbm__max_depth=4, lgbm__min_child_samples=50, lgbm__n_estimators=270, lgbm__num_leaves=182; accuracy: (train=0.950, test=0.950) roc_auc: (train=0.941, test=0.939) total time=  50.7s
# [CV 2/4] END lgbm__learning_rate=0.008548100214480913, lgbm__max_depth=3, lgbm__min_child_samples=77, lgbm__n_estimators=588, lgbm__num_leaves=145; accuracy: (train=0.949, test=0.948) roc_auc: (train=0.930, test=0.929) total time= 1.4min
# [CV 2/4] END lgbm__learning_rate=0.05565296745349411, lgbm__max_depth=-3, lgbm__min_child_samples=51, lgbm__n_estimators=351, lgbm__num_leaves=111; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.965, test=0.944) total time= 1.3min[CV 3/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.954, test=0.945) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.965, test=0.945) total time= 1.3min
# [CV 3/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.939, test=0.937) total time= 2.0min
# [CV 2/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.946, test=0.946) roc_auc: (train=0.919, test=0.918) total time=  38.1s
# [CV 2/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.944) roc_auc: (train=0.900, test=0.899) total time=  32.4s
# [CV 2/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.946, test=0.946) roc_auc: (train=0.917, test=0.916) total time=  57.4s
# [CV 2/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.961, test=0.944) total time= 2.0min
# [CV 2/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.955, test=0.944) total time= 1.3min
# [CV 1/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.943) total time= 2.3min
# [CV 1/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.946, test=0.938) total time= 1.8min
# [CV 1/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.941, test=0.935) total time= 1.4min
# [CV 1/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.949, test=0.943) total time= 1.3min
# [CV 1/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.975, test=0.943) total time= 1.6min
# [CV 1/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.972, test=0.943) total time= 1.9min
# [CV 1/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.937, test=0.934) total time=  46.5s
# [CV 1/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.969, test=0.942) total time= 1.5min
# [CV 1/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.951, test=0.943) total time= 2.5min
# [CV 1/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.950, test=0.943) total time= 1.8min
# [CV 1/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.948, test=0.947) roc_auc: (train=0.932, test=0.929) total time= 1.2min
# [CV 1/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.943) total time= 2.3min
# [CV 1/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.952, test=0.943) total time= 1.7min
# [CV 1/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.970, test=0.943) total time= 1.4min
# [CV 1/4] END lgbm__learning_rate=0.004266133482097422, lgbm__max_depth=7, lgbm__min_child_samples=82, lgbm__n_estimators=576, lgbm__num_leaves=176; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.939, test=0.933) total time= 2.8min
# [CV 1/4] END lgbm__learning_rate=0.04363153129847165, lgbm__max_depth=4, lgbm__min_child_samples=75, lgbm__n_estimators=570, lgbm__num_leaves=169; accuracy: (train=0.951, test=0.951) roc_auc: (train=0.947, test=0.942) total time= 1.6min
# [CV 2/4] END lgbm__learning_rate=0.04064314766640962, lgbm__max_depth=4, lgbm__min_child_samples=72, lgbm__n_estimators=338, lgbm__num_leaves=139; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.943, test=0.941) total time=  59.1s
# [CV 2/4] END lgbm__learning_rate=0.05498062156658356, lgbm__max_depth=-1, lgbm__min_child_samples=88, lgbm__n_estimators=448, lgbm__num_leaves=177; accuracy: (train=0.958, test=0.951) roc_auc: (train=0.976, test=0.944) total time= 1.7min
# [CV 2/4] END lgbm__learning_rate=0.030230751361551147, lgbm__max_depth=-1, lgbm__min_child_samples=89, lgbm__n_estimators=426, lgbm__num_leaves=162; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.963, test=0.944) total time= 2.2min
# [CV 3/4] END lgbm__learning_rate=0.059912934536355836, lgbm__max_depth=7, lgbm__min_child_samples=84, lgbm__n_estimators=418, lgbm__num_leaves=192; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.958, test=0.945) total time= 1.8min
# [CV 3/4] END lgbm__learning_rate=0.06581588203970642, lgbm__max_depth=3, lgbm__min_child_samples=65, lgbm__n_estimators=327, lgbm__num_leaves=98; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.942, test=0.941) total time=  49.3s
# [CV 4/4] END lgbm__learning_rate=0.0266292630148277, lgbm__max_depth=9, lgbm__min_child_samples=56, lgbm__n_estimators=527, lgbm__num_leaves=83; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.954, test=0.946) total time= 2.3min
# [CV 3/4] END lgbm__learning_rate=0.0424941284161412, lgbm__max_depth=6, lgbm__min_child_samples=84, lgbm__n_estimators=335, lgbm__num_leaves=154; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.949, test=0.945) total time= 1.2min
# [CV 3/4] END lgbm__learning_rate=0.08168766138390322, lgbm__max_depth=2, lgbm__min_child_samples=80, lgbm__n_estimators=393, lgbm__num_leaves=52; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.939, test=0.938) total time=  47.8s
# [CV 3/4] END lgbm__learning_rate=0.03417034837206397, lgbm__max_depth=4, lgbm__min_child_samples=50, lgbm__n_estimators=270, lgbm__num_leaves=182; accuracy: (train=0.950, test=0.950) roc_auc: (train=0.941, test=0.940) total time=  50.5s
# [CV 3/4] END lgbm__learning_rate=0.008548100214480913, lgbm__max_depth=3, lgbm__min_child_samples=77, lgbm__n_estimators=588, lgbm__num_leaves=145; accuracy: (train=0.949, test=0.948) roc_auc: (train=0.930, test=0.930) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.05565296745349411, lgbm__max_depth=-3, lgbm__min_child_samples=51, lgbm__n_estimators=351, lgbm__num_leaves=111; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.965, test=0.945) total time= 1.3min[CV 1/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.954, test=0.943) total time= 1.4min
# [CV 2/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.966, test=0.944) total time= 1.3min
# [CV 2/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.939, test=0.936) total time= 1.9min
# [CV 1/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.946, test=0.946) roc_auc: (train=0.919, test=0.916) total time=  37.7s
# [CV 1/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.943) roc_auc: (train=0.901, test=0.899) total time=  33.3s
# [CV 1/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.946, test=0.945) roc_auc: (train=0.918, test=0.915) total time=  54.2s
# [CV 1/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.961, test=0.944) total time= 2.1min
# [CV 3/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.954, test=0.945) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.959, test=0.946) total time= 2.4min
# [CV 3/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.950) roc_auc: (train=0.945, test=0.941) total time= 1.9min
# [CV 4/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.951) roc_auc: (train=0.940, test=0.937) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.952) roc_auc: (train=0.948, test=0.945) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.952) roc_auc: (train=0.974, test=0.945) total time= 1.7min
# [CV 4/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.971, test=0.946) total time= 2.0min
# [CV 4/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.949, test=0.950) roc_auc: (train=0.936, test=0.937) total time=  44.6s
# [CV 4/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.968, test=0.945) total time= 1.6min
# [CV 4/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.950, test=0.945) total time= 2.4min
# [CV 4/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.952, test=0.952) roc_auc: (train=0.950, test=0.946) total time= 1.8min
# [CV 4/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.948, test=0.949) roc_auc: (train=0.930, test=0.931) total time= 1.2min
# [CV 4/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.954, test=0.952) roc_auc: (train=0.959, test=0.946) total time= 2.6min
# [CV 4/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.952, test=0.946) total time= 1.6min
# [CV 4/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.970, test=0.946) total time= 1.6min
# [CV 4/4] END lgbm__learning_rate=0.004266133482097422, lgbm__max_depth=7, lgbm__min_child_samples=82, lgbm__n_estimators=576, lgbm__num_leaves=176; accuracy: (train=0.950, test=0.950) roc_auc: (train=0.938, test=0.935) total time= 2.7min
# [CV 4/4] END lgbm__learning_rate=0.04363153129847165, lgbm__max_depth=4, lgbm__min_child_samples=75, lgbm__n_estimators=570, lgbm__num_leaves=169; accuracy: (train=0.951, test=0.952) roc_auc: (train=0.946, test=0.945) total time= 1.5min
# [CV 4/4] END lgbm__learning_rate=0.04064314766640962, lgbm__max_depth=4, lgbm__min_child_samples=72, lgbm__n_estimators=338, lgbm__num_leaves=139; accuracy: (train=0.951, test=0.951) roc_auc: (train=0.943, test=0.942) total time=  55.9s
# [CV 4/4] END lgbm__learning_rate=0.05498062156658356, lgbm__max_depth=-1, lgbm__min_child_samples=88, lgbm__n_estimators=448, lgbm__num_leaves=177; accuracy: (train=0.957, test=0.952) roc_auc: (train=0.975, test=0.946) total time= 1.8min
# [CV 4/4] END lgbm__learning_rate=0.030230751361551147, lgbm__max_depth=-1, lgbm__min_child_samples=89, lgbm__n_estimators=426, lgbm__num_leaves=162; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.963, test=0.946) total time= 2.0min
# [CV 4/4] END lgbm__learning_rate=0.059912934536355836, lgbm__max_depth=7, lgbm__min_child_samples=84, lgbm__n_estimators=418, lgbm__num_leaves=192; accuracy: (train=0.954, test=0.952) roc_auc: (train=0.959, test=0.946) total time= 1.7min
# [CV 4/4] END lgbm__learning_rate=0.06581588203970642, lgbm__max_depth=3, lgbm__min_child_samples=65, lgbm__n_estimators=327, lgbm__num_leaves=98; accuracy: (train=0.950, test=0.951) roc_auc: (train=0.942, test=0.942) total time=  47.6s
# [CV 3/4] END lgbm__learning_rate=0.0266292630148277, lgbm__max_depth=9, lgbm__min_child_samples=56, lgbm__n_estimators=527, lgbm__num_leaves=83; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.954, test=0.945) total time= 2.3min
# [CV 4/4] END lgbm__learning_rate=0.0424941284161412, lgbm__max_depth=6, lgbm__min_child_samples=84, lgbm__n_estimators=335, lgbm__num_leaves=154; accuracy: (train=0.952, test=0.952) roc_auc: (train=0.949, test=0.945) total time= 1.2min
# [CV 4/4] END lgbm__learning_rate=0.08168766138390322, lgbm__max_depth=2, lgbm__min_child_samples=80, lgbm__n_estimators=393, lgbm__num_leaves=52; accuracy: (train=0.949, test=0.950) roc_auc: (train=0.939, test=0.939) total time=  48.9s
# [CV 4/4] END lgbm__learning_rate=0.03417034837206397, lgbm__max_depth=4, lgbm__min_child_samples=50, lgbm__n_estimators=270, lgbm__num_leaves=182; accuracy: (train=0.950, test=0.951) roc_auc: (train=0.940, test=0.940) total time=  47.3s
# [CV 4/4] END lgbm__learning_rate=0.008548100214480913, lgbm__max_depth=3, lgbm__min_child_samples=77, lgbm__n_estimators=588, lgbm__num_leaves=145; accuracy: (train=0.948, test=0.949) roc_auc: (train=0.930, test=0.931) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.05565296745349411, lgbm__max_depth=-3, lgbm__min_child_samples=51, lgbm__n_estimators=351, lgbm__num_leaves=111; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.965, test=0.946) total time= 1.3min1
# Fitting 4 folds for each of 40 candidates, totalling 160 fits
#
# [CV 3/4] END lgbm__learning_rate=0.05264365326761174, lgbm__max_depth=0, lgbm__min_child_samples=80, lgbm__n_estimators=539, lgbm__num_leaves=192; accuracy: (train=0.959, test=0.951) roc_auc: (train=0.980, test=0.945) total time= 2.2min
# [CV 3/4] END lgbm__learning_rate=0.020360982067240286, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=530, lgbm__num_leaves=47; accuracy: (train=0.948, test=0.948) roc_auc: (train=0.929, test=0.928) total time= 1.1min
# [CV 3/4] END lgbm__learning_rate=0.05943504190503517, lgbm__max_depth=4, lgbm__min_child_samples=50, lgbm__n_estimators=527, lgbm__num_leaves=182; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.947, test=0.944) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.09938343789941735, lgbm__max_depth=-3, lgbm__min_child_samples=91, lgbm__n_estimators=353, lgbm__num_leaves=183; accuracy: (train=0.960, test=0.951) roc_auc: (train=0.982, test=0.944) total time= 1.3min
# [CV 3/4] END lgbm__learning_rate=0.0976070536896846, lgbm__max_depth=7, lgbm__min_child_samples=59, lgbm__n_estimators=438, lgbm__num_leaves=96; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.965, test=0.945) total time= 1.8min
# [CV 3/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.955, test=0.946) total time= 1.5min
# [CV 3/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.967, test=0.945) total time= 1.3min
# [CV 2/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.941, test=0.938) total time= 2.2min
# [CV 3/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.947, test=0.946) roc_auc: (train=0.922, test=0.921) total time=  35.4s
# [CV 3/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.944) roc_auc: (train=0.905, test=0.904) total time=  31.4s
# [CV 3/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.946, test=0.946) roc_auc: (train=0.921, test=0.921) total time=  53.4s
# [CV 3/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.962, test=0.946) total time= 2.0min
# [CV 4/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.955, test=0.946) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.946) total time= 2.7min
# [CV 4/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.946, test=0.942) total time= 1.8min
# [CV 3/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.942, test=0.939) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.949, test=0.945) total time= 1.4min
# /opt/conda/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [CV 3/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.975, test=0.945) total time= 1.7min
# [CV 3/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.973, test=0.946) total time= 1.9min
# [CV 3/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.938, test=0.937) total time=  43.6s
# [CV 3/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.969, test=0.945) total time= 1.5min
# [CV 3/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.951, test=0.945) total time= 2.4min
# [CV 3/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.950, test=0.946) total time= 1.7min
# [CV 3/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.949, test=0.948) roc_auc: (train=0.933, test=0.933) total time= 1.2min
# [CV 3/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.961, test=0.946) total time= 2.7min
# [CV 4/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.952, test=0.947) total time= 1.6min
# [CV 4/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.971, test=0.946) total time= 1.5min
#
# [CV 2/4] END lgbm__learning_rate=0.05264365326761174, lgbm__max_depth=0, lgbm__min_child_samples=80, lgbm__n_estimators=539, lgbm__num_leaves=192; accuracy: (train=0.959, test=0.951) roc_auc: (train=0.980, test=0.943) total time= 2.3min
# [CV 2/4] END lgbm__learning_rate=0.020360982067240286, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=530, lgbm__num_leaves=47; accuracy: (train=0.948, test=0.948) roc_auc: (train=0.929, test=0.928) total time= 1.1min
# [CV 2/4] END lgbm__learning_rate=0.05943504190503517, lgbm__max_depth=4, lgbm__min_child_samples=50, lgbm__n_estimators=527, lgbm__num_leaves=182; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.947, test=0.943) total time= 1.3min
# [CV 2/4] END lgbm__learning_rate=0.09938343789941735, lgbm__max_depth=-3, lgbm__min_child_samples=91, lgbm__n_estimators=353, lgbm__num_leaves=183; accuracy: (train=0.960, test=0.951) roc_auc: (train=0.982, test=0.942) total time= 1.3min
# [CV 2/4] END lgbm__learning_rate=0.0976070536896846, lgbm__max_depth=7, lgbm__min_child_samples=59, lgbm__n_estimators=438, lgbm__num_leaves=96; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.966, test=0.943) total time= 1.8min
# [CV 2/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.955, test=0.945) total time= 1.3min
# [CV 1/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.967, test=0.943) total time= 1.2min
# [CV 1/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.942, test=0.937) total time= 2.1min
# [CV 1/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.947, test=0.946) roc_auc: (train=0.923, test=0.920) total time=  36.2s
# [CV 1/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.943) roc_auc: (train=0.905, test=0.903) total time=  31.7s
# [CV 1/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.947, test=0.946) roc_auc: (train=0.922, test=0.919) total time=  55.1s
# [CV 1/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.962, test=0.944) total time= 2.1min
# [CV 1/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.955, test=0.943) total time= 1.4min
# [CV 1/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.944) total time= 2.6min
# [CV 2/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.947, test=0.941) total time= 1.8min
# [CV 2/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.942, test=0.938) total time= 1.3min
# [CV 2/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.949, test=0.944) total time= 1.4min
# [CV 1/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.975, test=0.943) total time= 1.7min
# [CV 1/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.973, test=0.943) total time= 1.6min
# [CV 1/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.939, test=0.936) total time=  46.2s
# [CV 1/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.970, test=0.943) total time= 1.5min
# [CV 2/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.951, test=0.944) total time= 2.5min
# [CV 2/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.951, test=0.944) total time= 1.7min
# [CV 1/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.949, test=0.948) roc_auc: (train=0.934, test=0.931) total time= 1.2min
# [CV 1/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.944) total time= 2.6min
# [CV 1/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.953, test=0.944) total time= 1.5min
# [CV 1/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.972, test=0.943) total time= 1.4min
# ...
# [CV 1/4] END lgbm__learning_rate=0.09938343789941735, lgbm__max_depth=-3, lgbm__min_child_samples=91, lgbm__n_estimators=353, lgbm__num_leaves=183; accuracy: (train=0.960, test=0.951) roc_auc: (train=0.982, test=0.942) total time= 1.2min
# [CV 1/4] END lgbm__learning_rate=0.0976070536896846, lgbm__max_depth=7, lgbm__min_child_samples=59, lgbm__n_estimators=438, lgbm__num_leaves=96; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.966, test=0.942) total time= 1.7min
# [CV 1/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.955, test=0.944) total time= 1.5min
# [CV 4/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.967, test=0.946) total time= 1.3min
# [CV 4/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.951, test=0.951) roc_auc: (train=0.941, test=0.939) total time= 2.2min
# [CV 4/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.946, test=0.947) roc_auc: (train=0.922, test=0.923) total time=  35.3s
# [CV 4/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.944) roc_auc: (train=0.904, test=0.906) total time=  31.2s
# [CV 4/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.946, test=0.947) roc_auc: (train=0.921, test=0.923) total time=  52.3s
# [CV 4/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.954, test=0.952) roc_auc: (train=0.961, test=0.946) total time= 1.9min
# [CV 2/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.955, test=0.944) total time= 1.3min
# [CV 2/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.960, test=0.944) total time= 2.4min
# [CV 1/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.947, test=0.940) total time= 1.7min
# [CV 1/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.943, test=0.937) total time= 1.3min
# [CV 1/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.949, test=0.943) total time= 1.5min
# [CV 2/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.976, test=0.944) total time= 1.7min
# [CV 2/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.973, test=0.944) total time= 1.6min
# [CV 2/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.949, test=0.949) roc_auc: (train=0.938, test=0.936) total time=  46.9s
# [CV 2/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.970, test=0.944) total time= 1.4min
# [CV 1/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.951, test=0.943) total time= 2.5min
# [CV 1/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.951, test=0.944) total time= 1.9min
# [CV 2/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.949, test=0.949) roc_auc: (train=0.934, test=0.932) total time= 1.2min
# [CV 2/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.961, test=0.944) total time= 2.4min
# [CV 2/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.953, test=0.945) total time= 1.6min
# [CV 2/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.971, test=0.944) total time= 1.5min
# [CV 2/4] END lgbm__learning_rate=0.004266133482097422, lgbm__max_depth=7, lgbm__min_child_samples=82, lgbm__n_estimators=576, lgbm__num_leaves=176; accuracy: (train=0.950, test=0.949) roc_auc: (train=0.940, test=0.936) total time= 2.9min
# [CV 2/4] END lgbm__learning_rate=0.04363153129847165, lgbm__max_depth=4, lgbm__min_child_samples=75, lgbm__n_estimators=570, lgbm__num_leaves=169; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.947, test=0.944) total time= 1.5min
# [CV 3/4] END lgbm__learning_rate=0.04064314766640962, lgbm__max_depth=4, lgbm__min_child_samples=72, lgbm__n_estimators=338, lgbm__num_leaves=139; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.944, test=0.943) total time=  59.1s
# [CV 3/4] END lgbm__learning_rate=0.05498062156658356, lgbm__max_depth=-1, lgbm__min_child_samples=88, lgbm__n_estimators=448, lgbm__num_leaves=177; accuracy: (train=0.957, test=0.951) roc_auc: (train=0.976, test=0.945) total time= 1.8min
# [CV 3/4] END lgbm__learning_rate=0.030230751361551147, lgbm__max_depth=-1, lgbm__min_child_samples=89, lgbm__n_estimators=426, lgbm__num_leaves=162; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.964, test=0.946) total time= 1.9min
# [CV 2/4] END lgbm__learning_rate=0.059912934536355836, lgbm__max_depth=7, lgbm__min_child_samples=84, lgbm__n_estimators=418, lgbm__num_leaves=192; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.960, test=0.944) total time= 1.7min
# [CV 2/4] END lgbm__learning_rate=0.06581588203970642, lgbm__max_depth=3, lgbm__min_child_samples=65, lgbm__n_estimators=327, lgbm__num_leaves=98; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.943, test=0.941) total time=  50.0s
# [CV 2/4] END lgbm__learning_rate=0.0266292630148277, lgbm__max_depth=9, lgbm__min_child_samples=56, lgbm__n_estimators=527, lgbm__num_leaves=83; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.956, test=0.945) total time= 2.2min
# [CV 4/4] END lgbm__learning_rate=0.05264365326761174, lgbm__max_depth=0, lgbm__min_child_samples=80, lgbm__n_estimators=539, lgbm__num_leaves=192; accuracy: (train=0.959, test=0.952) roc_auc: (train=0.980, test=0.945) total time= 2.2min
# [CV 4/4] END lgbm__learning_rate=0.020360982067240286, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=530, lgbm__num_leaves=47; accuracy: (train=0.948, test=0.948) roc_auc: (train=0.929, test=0.930) total time= 1.1min
# [CV 4/4] END lgbm__learning_rate=0.05943504190503517, lgbm__max_depth=4, lgbm__min_child_samples=50, lgbm__n_estimators=527, lgbm__num_leaves=182; accuracy: (train=0.951, test=0.952) roc_auc: (train=0.947, test=0.945) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.09938343789941735, lgbm__max_depth=-3, lgbm__min_child_samples=91, lgbm__n_estimators=353, lgbm__num_leaves=183; accuracy: (train=0.960, test=0.952) roc_auc: (train=0.982, test=0.944) total time= 1.3min
# [CV 4/4] END lgbm__learning_rate=0.0976070536896846, lgbm__max_depth=7, lgbm__min_child_samples=59, lgbm__n_estimators=438, lgbm__num_leaves=96; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.966, test=0.945) total time= 1.7min
# [CV 4/4] END lgbm__learning_rate=0.06822785586307918, lgbm__max_depth=6, lgbm__min_child_samples=90, lgbm__n_estimators=401, lgbm__num_leaves=99; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.955, test=0.946) total time= 1.3min
# [CV 2/4] END lgbm__learning_rate=0.08180499633648478, lgbm__max_depth=-2, lgbm__min_child_samples=73, lgbm__n_estimators=454, lgbm__num_leaves=66; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.967, test=0.944) total time= 1.4min
# [CV 3/4] END lgbm__learning_rate=0.005669572050695326, lgbm__max_depth=-2, lgbm__min_child_samples=98, lgbm__n_estimators=421, lgbm__num_leaves=90; accuracy: (train=0.951, test=0.950) roc_auc: (train=0.940, test=0.938) total time= 1.9min
# [CV 2/4] END lgbm__learning_rate=0.07797930281899398, lgbm__max_depth=1, lgbm__min_child_samples=73, lgbm__n_estimators=330, lgbm__num_leaves=171; accuracy: (train=0.947, test=0.946) roc_auc: (train=0.922, test=0.921) total time=  35.9s
# [CV 2/4] END lgbm__learning_rate=0.03467723072241872, lgbm__max_depth=1, lgbm__min_child_samples=89, lgbm__n_estimators=279, lgbm__num_leaves=78; accuracy: (train=0.944, test=0.944) roc_auc: (train=0.905, test=0.904) total time=  32.0s
# [CV 2/4] END lgbm__learning_rate=0.010361309329775258, lgbm__max_depth=2, lgbm__min_child_samples=96, lgbm__n_estimators=428, lgbm__num_leaves=93; accuracy: (train=0.946, test=0.946) roc_auc: (train=0.921, test=0.920) total time=  52.4s
# [CV 2/4] END lgbm__learning_rate=0.030226911595916162, lgbm__max_depth=-3, lgbm__min_child_samples=71, lgbm__n_estimators=439, lgbm__num_leaves=130; accuracy: (train=0.955, test=0.951) roc_auc: (train=0.962, test=0.945) total time= 2.1min
# [CV 3/4] END lgbm__learning_rate=0.04197553539636337, lgbm__max_depth=7, lgbm__min_child_samples=55, lgbm__n_estimators=340, lgbm__num_leaves=127; accuracy: (train=0.954, test=0.951) roc_auc: (train=0.955, test=0.946) total time= 1.5min
# [CV 4/4] END lgbm__learning_rate=0.029880160409220303, lgbm__max_depth=8, lgbm__min_child_samples=51, lgbm__n_estimators=531, lgbm__num_leaves=145; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.960, test=0.946) total time= 2.5min
# [CV 3/4] END lgbm__learning_rate=0.008761383660001487, lgbm__max_depth=-2, lgbm__min_child_samples=91, lgbm__n_estimators=323, lgbm__num_leaves=192; accuracy: (train=0.952, test=0.951) roc_auc: (train=0.946, test=0.942) total time= 1.8min
# [CV 4/4] END lgbm__learning_rate=0.007926447564538142, lgbm__max_depth=9, lgbm__min_child_samples=85, lgbm__n_estimators=288, lgbm__num_leaves=145; accuracy: (train=0.951, test=0.951) roc_auc: (train=0.942, test=0.939) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.03220897936952004, lgbm__max_depth=8, lgbm__min_child_samples=50, lgbm__n_estimators=351, lgbm__num_leaves=42; accuracy: (train=0.952, test=0.952) roc_auc: (train=0.949, test=0.946) total time= 1.4min
# [CV 4/4] END lgbm__learning_rate=0.08106581636464107, lgbm__max_depth=-3, lgbm__min_child_samples=88, lgbm__n_estimators=581, lgbm__num_leaves=90; accuracy: (train=0.957, test=0.952) roc_auc: (train=0.975, test=0.946) total time= 1.7min
# [CV 4/4] END lgbm__learning_rate=0.047623813470984225, lgbm__max_depth=-1, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=153; accuracy: (train=0.956, test=0.952) roc_auc: (train=0.973, test=0.946) total time= 1.9min
# [CV 4/4] END lgbm__learning_rate=0.06317125445882107, lgbm__max_depth=2, lgbm__min_child_samples=79, lgbm__n_estimators=349, lgbm__num_leaves=136; accuracy: (train=0.949, test=0.950) roc_auc: (train=0.938, test=0.939) total time=  44.4s
# [CV 4/4] END lgbm__learning_rate=0.08985617542080104, lgbm__max_depth=-2, lgbm__min_child_samples=95, lgbm__n_estimators=549, lgbm__num_leaves=62; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.969, test=0.946) total time= 1.5min
# [CV 4/4] END lgbm__learning_rate=0.018442025303130362, lgbm__max_depth=8, lgbm__min_child_samples=94, lgbm__n_estimators=556, lgbm__num_leaves=72; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.951, test=0.946) total time= 2.4min
# [CV 4/4] END lgbm__learning_rate=0.02885453422103175, lgbm__max_depth=8, lgbm__min_child_samples=77, lgbm__n_estimators=429, lgbm__num_leaves=54; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.950, test=0.946) total time= 1.7min
# [CV 4/4] END lgbm__learning_rate=0.021538671086664508, lgbm__max_depth=2, lgbm__min_child_samples=82, lgbm__n_estimators=587, lgbm__num_leaves=166; accuracy: (train=0.948, test=0.949) roc_auc: (train=0.933, test=0.934) total time= 1.2min
# [CV 4/4] END lgbm__learning_rate=0.03139332037836162, lgbm__max_depth=8, lgbm__min_child_samples=91, lgbm__n_estimators=525, lgbm__num_leaves=198; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.960, test=0.946) total time= 2.4min
# [CV 3/4] END lgbm__learning_rate=0.07685975625559274, lgbm__max_depth=5, lgbm__min_child_samples=98, lgbm__n_estimators=534, lgbm__num_leaves=65; accuracy: (train=0.953, test=0.951) roc_auc: (train=0.953, test=0.946) total time= 1.6min
# [CV 3/4] END lgbm__learning_rate=0.07156184686255299, lgbm__max_depth=-3, lgbm__min_child_samples=90, lgbm__n_estimators=483, lgbm__num_leaves=95; accuracy: (train=0.956, test=0.951) roc_auc: (train=0.971, test=0.945) total time= 1.5min
# [CV 3/4] END lgbm__learning_rate=0.004266133482097422, lgbm__max_depth=7, lgbm__min_child_samples=82, lgbm__n_estimators=576, lgbm__num_leaves=176; accuracy: (train=0.950, test=0.950) roc_auc: (train=0.940, test=0.937) total time= 2.9min
# [CV 4/4] END lgbm__learning_rate=0.04363153129847165, lgbm__max_depth=4, lgbm__min_child_samples=75, lgbm__n_estimators=570, lgbm__num_leaves=169; accuracy: (train=0.951, test=0.952) roc_auc: (train=0.947, test=0.945) total time= 1.5min
# [CV 4/4] END lgbm__learning_rate=0.04064314766640962, lgbm__max_depth=4, lgbm__min_child_samples=72, lgbm__n_estimators=338, lgbm__num_leaves=139; accuracy: (train=0.951, test=0.952) roc_auc: (train=0.944, test=0.943) total time=  55.2s
# [CV 4/4] END lgbm__learning_rate=0.05498062156658356, lgbm__max_depth=-1, lgbm__min_child_samples=88, lgbm__n_estimators=448, lgbm__num_leaves=177; accuracy: (train=0.957, test=0.952) roc_auc: (train=0.977, test=0.946) total time= 1.8min
# [CV 4/4] END lgbm__learning_rate=0.030230751361551147, lgbm__max_depth=-1, lgbm__min_child_samples=89, lgbm__n_estimators=426, lgbm__num_leaves=162; accuracy: (train=0.955, test=0.952) roc_auc: (train=0.964, test=0.946) total time= 2.0min
# [CV 4/4] END lgbm__learning_rate=0.059912934536355836, lgbm__max_depth=7, lgbm__min_child_samples=84, lgbm__n_estimators=418, lgbm__num_leaves=192; accuracy: (train=0.954, test=0.952) roc_auc: (train=0.959, test=0.947) total time= 1.7min
# [CV 4/4] END lgbm__learning_rate=0.06581588203970642, lgbm__max_depth=3, lgbm__min_child_samples=65, lgbm__n_estimators=327, lgbm__num_leaves=98; accuracy: (train=0.951, test=0.951) roc_auc: (train=0.943, test=0.943) total time=  46.2s
# [CV 4/4] END lgbm__learning_rate=0.0266292630148277, lgbm__max_depth=9, lgbm__min_child_samples=56, lgbm__n_estimators=527, lgbm__num_leaves=83; accuracy: (train=0.953, test=0.952) roc_auc: (train=0.955, test=0.947) total time= 2.3min2

# %%
dict_results_lgbm[1]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       57.814052      0.354775        24.942893        0.336975
# 1       56.643465      0.209848        22.571567        0.712651
# 2       89.989086      6.395338        31.686865        0.816324
# 3       30.266797      0.656304         7.093850        0.116670
# 4       26.302572      0.244048         6.560417        0.155978
# 5       43.992972      1.505099        10.721162        0.103465
# 6       80.248247      3.801170        41.434220        0.390939
# 7       58.935284      2.851311        23.266590        0.782037
# 8       93.872564      5.213218        51.570973        1.278020
# 9       77.743178      0.669698        31.639978        1.806316
# 10      62.807324      0.445759        21.195299        1.650315
# 11      60.441194      3.506621        22.399509        2.115022
# 12      71.059197      3.172216        30.964886        4.323449
# 13      79.593084      3.687893        36.709708        3.051472
# 14      35.483242      0.906081         9.421765        0.122844
# 15      65.169206      2.184453        24.265787        3.659673
# 16      97.617085      4.908723        43.187928        2.181043
# 17      72.964002      4.007478        31.797948        2.524659
# 18      55.819755      1.638948        14.594817        0.755879
# 19      95.225024      6.251098        50.944677        2.260282
# 20      68.461480      3.156055        28.946799        2.088344
# 21      65.437823      2.492206        25.787127        3.047053
# 22     116.349145      7.868282        49.464236        2.020473
# 23      66.281537      2.737399        22.924272        1.110363
# 24      44.631242      2.139737        12.561409        0.586572
# 25      69.195122      0.399672        34.621462        2.993081
# 26      82.609532      4.858750        40.749305        1.561737
# 27      69.409806      3.648954        29.315586        4.121888
# 28      38.250774      1.321676        10.351022        0.321368
# 29      94.175071      6.231307        48.417503        2.045979
# 30      54.529247      3.289638        17.185101        0.869727
# 31      38.370893      0.810363        10.320734        0.351624
# 32      38.373634      1.609264        10.633121        0.293392
# 33      66.925361      2.711276        18.917554        2.182898
# 34      57.356952      3.191239        21.670487        2.162821
# 35      88.052916      3.538072        45.803734        1.207645
# 36      51.576813      1.952057        13.658592        0.678109
# 37      61.389821      2.603159        21.969914        2.052121
# 38      53.663802      0.473566        22.363980        1.621843
# 39      70.906299      3.070108        33.879014        2.518233
#
#    param_lgbm__learning_rate param_lgbm__max_depth  \
# 0                   0.068228                     6
# 1                   0.081805                    -2
# 2                    0.00567                    -2
# 3                   0.077979                     1
# 4                   0.034677                     1
# 5                   0.010361                     2
# 6                   0.030227                    -3
# 7                   0.041976                     7
# 8                    0.02988                     8
# 9                   0.008761                    -2
# 10                  0.007926                     9
# 11                  0.032209                     8
# 12                  0.081066                    -3
# 13                  0.047624                    -1
# 14                  0.063171                     2
# 15                  0.089856                    -2
# 16                  0.018442                     8
# 17                  0.028855                     8
# 18                  0.021539                     2
# 19                  0.031393                     8
# 20                   0.07686                     5
# 21                  0.071562                    -3
# 22                  0.004266                     7
# 23                  0.043632                     4
# 24                  0.040643                     4
# 25                  0.054981                    -1
# 26                  0.030231                    -1
# 27                  0.059913                     7
# 28                  0.065816                     3
# 29                  0.026629                     9
# 30                  0.042494                     6
# 31                  0.081688                     2
# 32                   0.03417                     4
# 33                  0.008548                     3
# 34                  0.055653                    -3
# 35                  0.052644                     0
# 36                  0.020361                     2
# 37                  0.059435                     4
# 38                  0.099383                    -3
# 39                  0.097607                     7
#
#    param_lgbm__min_child_samples param_lgbm__n_estimators  \
# 0                             90                      401
# 1                             73                      454
# 2                             98                      421
# 3                             73                      330
# 4                             89                      279
# 5                             96                      428
# 6                             71                      439
# 7                             55                      340
# 8                             51                      531
# 9                             91                      323
# 10                            85                      288
# 11                            50                      351
# 12                            88                      581
# 13                            90                      483
# 14                            79                      349
# 15                            95                      549
# 16                            94                      556
# 17                            77                      429
# 18                            82                      587
# 19                            91                      525
# 20                            98                      534
# 21                            90                      483
# 22                            82                      576
# 23                            75                      570
# 24                            72                      338
# 25                            88                      448
# 26                            89                      426
# 27                            84                      418
# 28                            65                      327
# 29                            56                      527
# 30                            84                      335
# 31                            80                      393
# 32                            50                      270
# 33                            77                      588
# 34                            51                      351
# 35                            80                      539
# 36                            79                      530
# 37                            50                      527
# 38                            91                      353
# 39                            59                      438
#
#    param_lgbm__num_leaves                                             params  \
# 0                      99  {'lgbm__learning_rate': 0.06822785586307918, '...
# 1                      66  {'lgbm__learning_rate': 0.08180499633648478, '...
# 2                      90  {'lgbm__learning_rate': 0.005669572050695326, ...
# 3                     171  {'lgbm__learning_rate': 0.07797930281899398, '...
# 4                      78  {'lgbm__learning_rate': 0.03467723072241872, '...
# 5                      93  {'lgbm__learning_rate': 0.010361309329775258, ...
# 6                     130  {'lgbm__learning_rate': 0.030226911595916162, ...
# 7                     127  {'lgbm__learning_rate': 0.04197553539636337, '...
# 8                     145  {'lgbm__learning_rate': 0.029880160409220303, ...
# 9                     192  {'lgbm__learning_rate': 0.008761383660001487, ...
# 10                    145  {'lgbm__learning_rate': 0.007926447564538142, ...
# 11                     42  {'lgbm__learning_rate': 0.03220897936952004, '...
# 12                     90  {'lgbm__learning_rate': 0.08106581636464107, '...
# 13                    153  {'lgbm__learning_rate': 0.047623813470984225, ...
# 14                    136  {'lgbm__learning_rate': 0.06317125445882107, '...
# 15                     62  {'lgbm__learning_rate': 0.08985617542080104, '...
# 16                     72  {'lgbm__learning_rate': 0.018442025303130362, ...
# 17                     54  {'lgbm__learning_rate': 0.02885453422103175, '...
# 18                    166  {'lgbm__learning_rate': 0.021538671086664508, ...
# 19                    198  {'lgbm__learning_rate': 0.03139332037836162, '...
# 20                     65  {'lgbm__learning_rate': 0.07685975625559274, '...
# 21                     95  {'lgbm__learning_rate': 0.07156184686255299, '...
# 22                    176  {'lgbm__learning_rate': 0.004266133482097422, ...
# 23                    169  {'lgbm__learning_rate': 0.04363153129847165, '...
# 24                    139  {'lgbm__learning_rate': 0.04064314766640962, '...
# 25                    177  {'lgbm__learning_rate': 0.05498062156658356, '...
# 26                    162  {'lgbm__learning_rate': 0.030230751361551147, ...
# 27                    192  {'lgbm__learning_rate': 0.059912934536355836, ...
# 28                     98  {'lgbm__learning_rate': 0.06581588203970642, '...
# 29                     83  {'lgbm__learning_rate': 0.0266292630148277, 'l...
# 30                    154  {'lgbm__learning_rate': 0.0424941284161412, 'l...
# 31                     52  {'lgbm__learning_rate': 0.08168766138390322, '...
# 32                    182  {'lgbm__learning_rate': 0.03417034837206397, '...
# 33                    145  {'lgbm__learning_rate': 0.008548100214480913, ...
# 34                    111  {'lgbm__learning_rate': 0.05565296745349411, '...
# 35                    192  {'lgbm__learning_rate': 0.05264365326761174, '...
# 36                     47  {'lgbm__learning_rate': 0.020360982067240286, ...
# 37                    182  {'lgbm__learning_rate': 0.05943504190503517, '...
# 38                    183  {'lgbm__learning_rate': 0.09938343789941735, '...
# 39                     96  {'lgbm__learning_rate': 0.0976070536896846, 'l...
#
#     ...  split3_test_accuracy  mean_test_accuracy  std_test_accuracy  \
# 0   ...              0.952109            0.951421           0.000399
# 1   ...              0.952055            0.951294           0.000451
# 2   ...              0.950509            0.949917           0.000354
# 3   ...              0.946953            0.946273           0.000407
# 4   ...              0.944264            0.943645           0.000504
# 5   ...              0.946657            0.945925           0.000528
# 6   ...              0.952091            0.951410           0.000406
# 7   ...              0.951922            0.951320           0.000351
# 8   ...              0.952100            0.951427           0.000393
# 9   ...              0.951261            0.950565           0.000445
# 10  ...              0.950651            0.949936           0.000431
# 11  ...              0.951973            0.951199           0.000453
# 12  ...              0.952109            0.951341           0.000444
# 13  ...              0.952109            0.951439           0.000394
# 14  ...              0.950076            0.949151           0.000553
# 15  ...              0.951763            0.951334           0.000270
# 16  ...              0.952014            0.951315           0.000404
# 17  ...              0.952100            0.951315           0.000454
# 18  ...              0.948791            0.948019           0.000495
# 19  ...              0.952146            0.951388           0.000442
# 20  ...              0.952059            0.951364           0.000440
# 21  ...              0.952046            0.951388           0.000403
# 22  ...              0.950176            0.949485           0.000421
# 23  ...              0.951704            0.950873           0.000492
# 24  ...              0.951312            0.950427           0.000514
# 25  ...              0.952082            0.951316           0.000447
# 26  ...              0.952187            0.951440           0.000433
# 27  ...              0.952027            0.951422           0.000355
# 28  ...              0.951252            0.950357           0.000525
# 29  ...              0.952169            0.951394           0.000454
# 30  ...              0.951868            0.951150           0.000423
# 31  ...              0.950418            0.949752           0.000387
# 32  ...              0.950637            0.949838           0.000464
# 33  ...              0.948955            0.948310           0.000417
# 34  ...              0.952068            0.951396           0.000395
# 35  ...              0.952027            0.951379           0.000397
# 36  ...              0.948449            0.947802           0.000402
# 37  ...              0.951736            0.951005           0.000445
# 38  ...              0.951863            0.951263           0.000365
# 39  ...              0.952123            0.951480           0.000372
#
#     rank_test_accuracy  split0_train_accuracy  split1_train_accuracy  \
# 0                    6               0.953358               0.953355
# 1                   20               0.955217               0.955223
# 2                   30               0.950619               0.950588
# 3                   38               0.946458               0.946382
# 4                   40               0.943875               0.943603
# 5                   39               0.946104               0.946022
# 6                    7               0.954807               0.954636
# 7                   16               0.953380               0.953393
# 8                    4               0.954702               0.954702
# 9                   26               0.951918               0.952068
# 10                  29               0.950859               0.950859
# 11                  22               0.952210               0.952144
# 12                  14               0.957325               0.957182
# 13                   3               0.956781               0.956682
# 14                  34               0.949599               0.949426
# 15                  15               0.955831               0.955693
# 16                  18               0.952804               0.952702
# 17                  18               0.952745               0.952685
# 18                  36               0.948368               0.948136
# 19                  10               0.954624               0.954650
# 20                  13               0.952883               0.952935
# 21                  10               0.956341               0.956073
# 22                  33               0.950140               0.950073
# 23                  25               0.951416               0.951404
# 24                  27               0.950840               0.950882
# 25                  17               0.957632               0.957556
# 26                   2               0.955209               0.955089
# 27                   5               0.954413               0.954448
# 28                  28               0.950698               0.950679
# 29                   9               0.953758               0.953580
# 30                  23               0.952400               0.952340
# 31                  32               0.950167               0.950067
# 32                  31               0.950268               0.950252
# 33                  35               0.948553               0.948567
# 34                   8               0.955170               0.955143
# 35                  12               0.959065               0.958721
# 36                  37               0.948227               0.947900
# 37                  24               0.951605               0.951736
# 38                  21               0.960058               0.959803
# 39                   1               0.956273               0.956352
#
#     split2_train_accuracy  split3_train_accuracy  mean_train_accuracy  \
# 0                0.953460               0.953169             0.953336
# 1                0.955246               0.954858             0.955136
# 2                0.950599               0.950321             0.950532
# 3                0.946459               0.946139             0.946360
# 4                0.943669               0.943589             0.943684
# 5                0.946102               0.945814             0.946010
# 6                0.954693               0.954399             0.954634
# 7                0.953466               0.953097             0.953334
# 8                0.954656               0.954519             0.954645
# 9                0.952055               0.951755             0.951949
# 10               0.950875               0.950695             0.950822
# 11               0.952299               0.952082             0.952184
# 12               0.957427               0.956797             0.957183
# 13               0.956755               0.956396             0.956653
# 14               0.949180               0.949053             0.949314
# 15               0.955974               0.955594             0.955773
# 16               0.952874               0.952533             0.952728
# 17               0.952796               0.952451             0.952669
# 18               0.948228               0.947958             0.948172
# 19               0.954612               0.954413             0.954575
# 20               0.953018               0.952644             0.952870
# 21               0.956234               0.955992             0.956160
# 22               0.950055               0.949868             0.950034
# 23               0.951540               0.951198             0.951389
# 24               0.950916               0.950605             0.950811
# 25               0.957616               0.957361             0.957541
# 26               0.955111               0.954845             0.955064
# 27               0.954535               0.954206             0.954401
# 28               0.950777               0.950433             0.950647
# 29               0.953822               0.953489             0.953662
# 30               0.952425               0.952109             0.952319
# 31               0.950122               0.949468             0.949956
# 32               0.950307               0.949874             0.950175
# 33               0.948506               0.948215             0.948460
# 34               0.954927               0.954785             0.955006
# 35               0.958823               0.958639             0.958812
# 36               0.947803               0.947558             0.947872
# 37               0.951786               0.951462             0.951647
# 38               0.959853               0.959521             0.959809
# 39               0.956287               0.955986             0.956224
#
#     std_train_accuracy
# 0             0.000105
# 1             0.000161
# 2             0.000122
# 3             0.000131
# 4             0.000114
# 5             0.000118
# 6             0.000149
# 7             0.000141
# 8             0.000075
# 9             0.000126
# 10            0.000074
# 11            0.000081
# 12            0.000239
# 13            0.000153
# 14            0.000212
# 15            0.000143
# 16            0.000128
# 17            0.000132
# 18            0.000149
# 19            0.000094
# 20            0.000139
# 21            0.000136
# 22            0.000101
# 23            0.000123
# 24            0.000122
# 25            0.000108
# 26            0.000134
# 27            0.000121
# 28            0.000129
# 29            0.000134
# 30            0.000125
# 31            0.000284
# 32            0.000175
# 33            0.000144
# 34            0.000158
# 35            0.000160
# 36            0.000240
# 37            0.000126
# 38            0.000192
# 39            0.000141
#
# [40 rows x 36 columns]

# %%
dict_results_lgbm[2]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       60.299151      3.609391        23.528423        1.267769
# 1       56.713781      2.393085        21.100888        1.606245
# 2       95.975707      6.345927        30.075379        1.728331
# 3       28.821760      0.673603         6.882810        0.306850
# 4       25.596562      0.385685         6.010258        0.119755
# 5       42.838229      1.348461        10.466051        0.517891
# 6       80.283895      5.291366        41.157383        1.594888
# 7       61.068681      3.830735        23.655150        1.472939
# 8       98.453525      6.731687        54.646398        1.992593
# 9       77.527042      0.741104        30.145871        2.006821
# 10      62.627762      0.683703        20.367722        2.407439
# 11      60.036101      3.432534        23.219121        0.876409
# 12      71.884566      2.765735        30.000462        3.538450
# 13      72.297552      0.819021        33.024359        5.753865
# 14      36.061496      1.606217         9.215515        0.419061
# 15      63.260230      2.370967        24.085847        3.375214
# 16     101.380586      6.422880        45.648901        1.272321
# 17      72.461655      4.023102        33.280953        1.029500
# 18      55.339345      1.685599        15.167839        0.630918
# 19      96.007031      6.606457        55.423378        1.126958
# 20      65.380972      0.548083        28.854163        2.400925
# 21      62.918140      2.484893        25.926104        3.706930
# 22     120.780704      6.622134        49.448518        2.274259
# 23      64.990710      0.319597        25.063970        3.729780
# 24      45.483729      1.687879        12.330424        0.406713
# 25      70.722230      2.885104        33.283145        3.884478
# 26      82.345181      4.820474        38.726567        4.169251
# 27      67.105596      3.058712        31.635930        4.044447
# 28      37.873383      1.331601        10.108893        0.166186
# 29      85.691755      1.002315        47.498522        4.114581
# 30      56.518252      2.952933        16.709239        0.719691
# 31      38.183163      0.839815         9.861506        0.133947
# 32      37.062465      2.004035        10.159199        0.248045
# 33      65.003516      0.187732        18.547921        1.314402
# 34      56.210808      2.915113        20.670147        0.977853
# 35      78.557224      0.766432        41.650112        3.095899
# 36      51.783713      2.065655        12.518842        0.341676
# 37      62.453205      2.597943        19.904025        1.152232
# 38      53.625612      2.203143        22.124713        2.049469
# 39      68.181024      3.809788        32.341212        4.429880
#
#    param_lgbm__learning_rate param_lgbm__max_depth  \
# 0                   0.068228                     6
# 1                   0.081805                    -2
# 2                    0.00567                    -2
# 3                   0.077979                     1
# 4                   0.034677                     1
# 5                   0.010361                     2
# 6                   0.030227                    -3
# 7                   0.041976                     7
# 8                    0.02988                     8
# 9                   0.008761                    -2
# 10                  0.007926                     9
# 11                  0.032209                     8
# 12                  0.081066                    -3
# 13                  0.047624                    -1
# 14                  0.063171                     2
# 15                  0.089856                    -2
# 16                  0.018442                     8
# 17                  0.028855                     8
# 18                  0.021539                     2
# 19                  0.031393                     8
# 20                   0.07686                     5
# 21                  0.071562                    -3
# 22                  0.004266                     7
# 23                  0.043632                     4
# 24                  0.040643                     4
# 25                  0.054981                    -1
# 26                  0.030231                    -1
# 27                  0.059913                     7
# 28                  0.065816                     3
# 29                  0.026629                     9
# 30                  0.042494                     6
# 31                  0.081688                     2
# 32                   0.03417                     4
# 33                  0.008548                     3
# 34                  0.055653                    -3
# 35                  0.052644                     0
# 36                  0.020361                     2
# 37                  0.059435                     4
# 38                  0.099383                    -3
# 39                  0.097607                     7
#
#    param_lgbm__min_child_samples param_lgbm__n_estimators  \
# 0                             90                      401
# 1                             73                      454
# 2                             98                      421
# 3                             73                      330
# 4                             89                      279
# 5                             96                      428
# 6                             71                      439
# 7                             55                      340
# 8                             51                      531
# 9                             91                      323
# 10                            85                      288
# 11                            50                      351
# 12                            88                      581
# 13                            90                      483
# 14                            79                      349
# 15                            95                      549
# 16                            94                      556
# 17                            77                      429
# 18                            82                      587
# 19                            91                      525
# 20                            98                      534
# 21                            90                      483
# 22                            82                      576
# 23                            75                      570
# 24                            72                      338
# 25                            88                      448
# 26                            89                      426
# 27                            84                      418
# 28                            65                      327
# 29                            56                      527
# 30                            84                      335
# 31                            80                      393
# 32                            50                      270
# 33                            77                      588
# 34                            51                      351
# 35                            80                      539
# 36                            79                      530
# 37                            50                      527
# 38                            91                      353
# 39                            59                      438
#
#    param_lgbm__num_leaves                                             params  \
# 0                      99  {'lgbm__learning_rate': 0.06822785586307918, '...
# 1                      66  {'lgbm__learning_rate': 0.08180499633648478, '...
# 2                      90  {'lgbm__learning_rate': 0.005669572050695326, ...
# 3                     171  {'lgbm__learning_rate': 0.07797930281899398, '...
# 4                      78  {'lgbm__learning_rate': 0.03467723072241872, '...
# 5                      93  {'lgbm__learning_rate': 0.010361309329775258, ...
# 6                     130  {'lgbm__learning_rate': 0.030226911595916162, ...
# 7                     127  {'lgbm__learning_rate': 0.04197553539636337, '...
# 8                     145  {'lgbm__learning_rate': 0.029880160409220303, ...
# 9                     192  {'lgbm__learning_rate': 0.008761383660001487, ...
# 10                    145  {'lgbm__learning_rate': 0.007926447564538142, ...
# 11                     42  {'lgbm__learning_rate': 0.03220897936952004, '...
# 12                     90  {'lgbm__learning_rate': 0.08106581636464107, '...
# 13                    153  {'lgbm__learning_rate': 0.047623813470984225, ...
# 14                    136  {'lgbm__learning_rate': 0.06317125445882107, '...
# 15                     62  {'lgbm__learning_rate': 0.08985617542080104, '...
# 16                     72  {'lgbm__learning_rate': 0.018442025303130362, ...
# 17                     54  {'lgbm__learning_rate': 0.02885453422103175, '...
# 18                    166  {'lgbm__learning_rate': 0.021538671086664508, ...
# 19                    198  {'lgbm__learning_rate': 0.03139332037836162, '...
# 20                     65  {'lgbm__learning_rate': 0.07685975625559274, '...
# 21                     95  {'lgbm__learning_rate': 0.07156184686255299, '...
# 22                    176  {'lgbm__learning_rate': 0.004266133482097422, ...
# 23                    169  {'lgbm__learning_rate': 0.04363153129847165, '...
# 24                    139  {'lgbm__learning_rate': 0.04064314766640962, '...
# 25                    177  {'lgbm__learning_rate': 0.05498062156658356, '...
# 26                    162  {'lgbm__learning_rate': 0.030230751361551147, ...
# 27                    192  {'lgbm__learning_rate': 0.059912934536355836, ...
# 28                     98  {'lgbm__learning_rate': 0.06581588203970642, '...
# 29                     83  {'lgbm__learning_rate': 0.0266292630148277, 'l...
# 30                    154  {'lgbm__learning_rate': 0.0424941284161412, 'l...
# 31                     52  {'lgbm__learning_rate': 0.08168766138390322, '...
# 32                    182  {'lgbm__learning_rate': 0.03417034837206397, '...
# 33                    145  {'lgbm__learning_rate': 0.008548100214480913, ...
# 34                    111  {'lgbm__learning_rate': 0.05565296745349411, '...
# 35                    192  {'lgbm__learning_rate': 0.05264365326761174, '...
# 36                     47  {'lgbm__learning_rate': 0.020360982067240286, ...
# 37                    182  {'lgbm__learning_rate': 0.05943504190503517, '...
# 38                    183  {'lgbm__learning_rate': 0.09938343789941735, '...
# 39                     96  {'lgbm__learning_rate': 0.0976070536896846, 'l...
#
#     ...  split3_test_accuracy  mean_test_accuracy  std_test_accuracy  \
# 0   ...              0.952205            0.951485           0.000429
# 1   ...              0.952223            0.951442           0.000459
# 2   ...              0.950810            0.950195           0.000373
# 3   ...              0.947359            0.946597           0.000455
# 4   ...              0.944204            0.943784           0.000372
# 5   ...              0.947035            0.946267           0.000542
# 6   ...              0.952292            0.951509           0.000466
# 7   ...              0.952178            0.951439           0.000427
# 8   ...              0.952251            0.951486           0.000471
# 9   ...              0.951471            0.950765           0.000408
# 10  ...              0.950765            0.950160           0.000380
# 11  ...              0.952214            0.951308           0.000525
# 12  ...              0.952187            0.951479           0.000410
# 13  ...              0.952237            0.951508           0.000464
# 14  ...              0.950432            0.949420           0.000590
# 15  ...              0.952164            0.951565           0.000360
# 16  ...              0.952155            0.951350           0.000469
# 17  ...              0.952087            0.951300           0.000459
# 18  ...              0.949456            0.948681           0.000478
# 19  ...              0.952223            0.951537           0.000416
# 20  ...              0.952351            0.951448           0.000527
# 21  ...              0.952150            0.951551           0.000351
# 22  ...              0.950404            0.949725           0.000430
# 23  ...              0.951904            0.950994           0.000537
# 24  ...              0.951512            0.950611           0.000521
# 25  ...              0.952296            0.951544           0.000446
# 26  ...              0.952214            0.951475           0.000447
# 27  ...              0.952178            0.951565           0.000384
# 28  ...              0.951343            0.950519           0.000482
# 29  ...              0.952210            0.951463           0.000437
# 30  ...              0.952141            0.951292           0.000494
# 31  ...              0.950856            0.950011           0.000500
# 32  ...              0.951065            0.950253           0.000469
# 33  ...              0.949274            0.948577           0.000421
# 34  ...              0.952210            0.951501           0.000420
# 35  ...              0.952055            0.951446           0.000364
# 36  ...              0.949132            0.948348           0.000504
# 37  ...              0.951954            0.951101           0.000497
# 38  ...              0.952150            0.951375           0.000454
# 39  ...              0.952164            0.951592           0.000343
#
#     rank_test_accuracy  split0_train_accuracy  split1_train_accuracy  \
# 0                   11               0.953444               0.953488
# 1                   17               0.955097               0.954922
# 2                   30               0.950872               0.950871
# 3                   38               0.946835               0.946727
# 4                   40               0.944055               0.943707
# 5                   39               0.946500               0.946391
# 6                    7               0.954650               0.954583
# 7                   18               0.953517               0.953453
# 8                   10               0.954805               0.954761
# 9                   26               0.952336               0.952252
# 10                  31               0.951242               0.951113
# 11                  21               0.952409               0.952372
# 12                  12               0.957074               0.956814
# 13                   8               0.956513               0.956220
# 14                  34               0.949942               0.949462
# 15                   2               0.955559               0.955608
# 16                  20               0.952980               0.952862
# 17                  22               0.952821               0.952792
# 18                  35               0.948973               0.948868
# 19                   6               0.954839               0.954784
# 20                  15               0.953077               0.952936
# 21                   4               0.956010               0.955706
# 22                  33               0.950455               0.950293
# 23                  25               0.951678               0.951641
# 24                  27               0.951192               0.951059
# 25                   5               0.957492               0.957112
# 26                  13               0.955181               0.955284
# 27                   2               0.954576               0.954518
# 28                  28               0.950916               0.950853
# 29                  14               0.953664               0.953758
# 30                  23               0.952556               0.952473
# 31                  32               0.950423               0.950375
# 32                  29               0.950713               0.950679
# 33                  36               0.948736               0.948784
# 34                   9               0.955009               0.954940
# 35                  16               0.958610               0.958373
# 36                  37               0.948658               0.948514
# 37                  24               0.951932               0.951892
# 38                  19               0.959562               0.959367
# 39                   1               0.956513               0.956410
#
#     split2_train_accuracy  split3_train_accuracy  mean_train_accuracy  \
# 0                0.953570               0.953286             0.953447
# 1                0.954940               0.954702             0.954915
# 2                0.950942               0.950685             0.950843
# 3                0.946818               0.946491             0.946718
# 4                0.943826               0.943659             0.943812
# 5                0.946364               0.946143             0.946350
# 6                0.954623               0.954336             0.954548
# 7                0.953623               0.953261             0.953463
# 8                0.954849               0.954568             0.954746
# 9                0.952369               0.952017             0.952243
# 10               0.951172               0.950965             0.951123
# 11               0.952456               0.952210             0.952362
# 12               0.957004               0.956729             0.956905
# 13               0.956393               0.956135             0.956315
# 14               0.949588               0.949386             0.949595
# 15               0.955598               0.955305             0.955517
# 16               0.953020               0.952672             0.952883
# 17               0.952863               0.952580             0.952764
# 18               0.948742               0.948497             0.948770
# 19               0.954846               0.954527             0.954749
# 20               0.953129               0.952828             0.952993
# 21               0.955948               0.955703             0.955842
# 22               0.950351               0.950076             0.950294
# 23               0.951766               0.951383             0.951617
# 24               0.951216               0.950803             0.951067
# 25               0.957326               0.957039             0.957242
# 26               0.955129               0.954760             0.955088
# 27               0.954635               0.954380             0.954527
# 28               0.950988               0.950611             0.950842
# 29               0.953744               0.953488             0.953664
# 30               0.952571               0.952311             0.952478
# 31               0.950310               0.949835             0.950236
# 32               0.950768               0.950315             0.950619
# 33               0.948763               0.948455             0.948685
# 34               0.954951               0.954743             0.954911
# 35               0.958460               0.958264             0.958427
# 36               0.948394               0.948199             0.948441
# 37               0.951995               0.951687             0.951876
# 38               0.959612               0.959118             0.959415
# 39               0.956446               0.956069             0.956360
#
#     std_train_accuracy
# 0             0.000103
# 1             0.000141
# 2             0.000095
# 3             0.000137
# 4             0.000153
# 5             0.000130
# 6             0.000125
# 7             0.000132
# 8             0.000107
# 9             0.000138
# 10            0.000102
# 11            0.000093
# 12            0.000139
# 13            0.000147
# 14            0.000213
# 15            0.000124
# 16            0.000135
# 17            0.000109
# 18            0.000177
# 19            0.000130
# 20            0.000118
# 21            0.000139
# 22            0.000138
# 23            0.000143
# 24            0.000164
# 25            0.000179
# 26            0.000198
# 27            0.000095
# 28            0.000142
# 29            0.000108
# 30            0.000103
# 31            0.000235
# 32            0.000178
# 33            0.000134
# 34            0.000100
# 35            0.000127
# 36            0.000168
# 37            0.000115
# 38            0.000194
# 39            0.000172
#
# [40 rows x 36 columns]

# %% [markdown]
# Wegschreiben der Ergebnisse

# %%
for i in range(2):
    dict_results_lgbm[i+1].to_csv(f"lgbm_pipeline_{i+1}_results.csv", index=False)
